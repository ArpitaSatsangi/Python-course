# %%
from PIL import Image

# %%
car = Image.open("car.png")

# %%
type(car)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
car
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=536x339 at 0x4D2FA30>

# %%
car.filename
# Out:
# 'car.png'

# %%
car.format_description
# Out:
# 'Portable network graphics'

# %% [markdown]
# # cropping images

# %%
pencils = Image.open("pencils.png")

# %%
pencils
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=919x572 at 0x511DD60>

# %%
pencils.size
# Out:
# (919, 572)

# %%
#upper pencil
x = 0
y = 0

w = 919/3
h = 572/10

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGBA size=306x57 at 0x512E490>

# %%
# bottom pencils
x = 0
y = 450

w = 919/3
h = 572

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGBA size=306x122 at 0x512EC70>

# %%
mac = Image.open("oldiemac.png")

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=919x576 at 0x512E040>

# %%
mac.size
# Out:
# (919, 576)

# %%
#only mac in the whole image
x = 919 * (2/5)
y = 576 /2

w = 919 * (3/5)
h = 576

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGBA size=183x288 at 0x51360D0>

# %%
computer = mac.crop((x,y,w,h))

# %%
mac.paste(im=computer, box=(0,0))

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=919x576 at 0x512E040>

# %%
mac.paste(im=computer, box=(370,0))

# %%
mac
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=919x576 at 0x512E040>

# %%
mac.size
# Out:
# (919, 576)

# %%
mac.resize((3000,500))
# Out:
# <PIL.Image.Image image mode=RGBA size=3000x500 at 0x51368B0>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGBA size=919x576 at 0x5136BB0>

# %% [markdown]
# # Color Transparency

# %%
red = Image.open("red.PNG")

# %%
red
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=297x301 at 0x512EE50>

# %%
red.putalpha(128)

# %%
red
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=297x301 at 0x512EE50>

# %%
blue = Image.open("blue.PNG")

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x512EB80>

# %%
blue.putalpha(0)

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x512EB80>

# %%
blue.putalpha(255)

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x512EB80>

# %%
blue.putalpha(128)

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x512EB80>

# %%
blue.paste(im = red, box = (0,0), mask = red)

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x512EB80>

# %%
blue.save("purple.PNG")

# %%
purple= Image.open("purple.PNG")

# %%
purple
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x513CD90>
